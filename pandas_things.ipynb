# %%
import pandas as pd

# %%
from IPython.core.display import HTML, Image
css = open('style/style-table.css').read() + open('style/style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
pd.read_csv('https://bit.ly/uforeports')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
data = pd.read_csv('https://bit.ly/uforeports',index_col='Time')

# %%
data['City']
# Out:
# Time
# 6/1/1930 22:00                    Ithaca
# 6/30/1930 20:00              Willingboro
# 2/15/1931 14:00                  Holyoke
# 6/1/1931 13:00                   Abilene
# 4/18/1933 19:00     New York Worlds Fair
# 9/15/1934 15:30              Valley City
# 6/15/1935 0:00               Crater Lake
# 7/15/1936 0:00                      Alma
# 10/15/1936 17:00                 Eklutna
# 6/15/1937 0:00                   Hubbard
# 8/15/1937 21:00                  Fontana
# 6/1/1939 20:00                  Waterloo
# 6/30/1939 20:00                   Belton
# 7/7/1939 2:00                     Keokuk
# 6/1/1941 13:00                 Ludington
# 7/2/1941 11:30               Forest Home
# 2/25/1942 0:00               Los Angeles
# 6/1/1942 22:30                 Hapeville
# 7/15/1942 1:00                    Oneida
# 4/30/1943 23:00               Bering Sea
# 6/1/1943 15:00                  Nebraska
# 8/15/1943 0:00                       NaN
# 8/15/1943 0:00                       NaN
# ...

# %%
data.loc[:,:]
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
data.loc[0:5,:] #.loc uses labels to index
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
# 5           Valley City             NaN           DISK    ND  9/15/1934 15:30

# %%
data.iloc[0:5,:] #.loc uses integers to index
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
data.loc[0:5,'City':'Shape Reported']
# Out:
#                    City Colors Reported Shape Reported
# 0                Ithaca             NaN       TRIANGLE
# 1           Willingboro             NaN          OTHER
# 2               Holyoke             NaN           OVAL
# 3               Abilene             NaN           DISK
# 4  New York Worlds Fair             NaN          LIGHT
# 5           Valley City             NaN           DISK

# %%
data.iloc[0:5,0:3]
# Out:
#                    City Colors Reported Shape Reported
# 0                Ithaca             NaN       TRIANGLE
# 1           Willingboro             NaN          OTHER
# 2               Holyoke             NaN           OVAL
# 3               Abilene             NaN           DISK
# 4  New York Worlds Fair             NaN          LIGHT

# %%
data.iloc[0:1,0:1]
# Out:
#      City
# 0  Ithaca

# %%
x = data.iloc[0:5,1]

# %%
y = data.iloc[0:5,3]

# %%
z = x.append(y)

# %%
z
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 0     NY
# 1     NJ
# 2     CO
# 3     KS
# 4     NY
# dtype: object

# %%
column_chosen = [1,3,2]

# %%
w = data.iloc[0:5,column_chosen]

# %%
w
# Out:
#   Colors Reported State Shape Reported
# 0             NaN    NY       TRIANGLE
# 1             NaN    NJ          OTHER
# 2             NaN    CO           OVAL
# 3             NaN    KS           DISK
# 4             NaN    NY          LIGHT

# %%
data.values
# Out:
# array([['Ithaca', nan, 'TRIANGLE', 'NY'],
#        ['Willingboro', nan, 'OTHER', 'NJ'],
#        ['Holyoke', nan, 'OVAL', 'CO'],
#        ...,
#        ['Eagle River', nan, nan, 'WI'],
#        ['Eagle River', 'RED', 'LIGHT', 'WI'],
#        ['Ybor', nan, 'OVAL', 'FL']], dtype=object)

# %%
drinks = pd.read_csv('https://bit.ly/drinksbycountry')

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       193 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.columns #columns is an attribute
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.loc[:,'country':'continent']
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
drinks.plot(kind ='bar')

# %%
drinks.head(10).loc[:,'wine_servings'].plot(kind = 'bar')
